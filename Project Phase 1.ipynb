# %%
# In this project we are going to analyze the dataset of Issues from Github that uses ChatGPT to review the PR's'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# missing_values = ["N/A", "na", "--", "-"] # TODO: Please add more garbage data there

# Load the data file
data = pd.read_json('20230914_080417_issue_sharings.json')
refactoring_df = pd.json_normalize(data["Sources"])

print("The data set has {} rows and {} columns".format(refactoring_df.shape[0], refactoring_df.shape[1]))

display(refactoring_df.head(200))  # top rows of the refactoring commit data
display(refactoring_df.dtypes.value_counts())  # data types of the columns


# Based on the initial analysis, we have 10 columns which are object type i.e. they contain categorical data 
# and 2 remaining columns which are of int data type
# Out:
# The data set has 422 rows and 13 columns
#       Type                                                URL         Author  \
# 0    issue       https://github.com/Tommie1236/mipsi/issues/3     Tommie1236
# 1    issue      https://github.com/ariel1985/aipages/issues/4      ariel1985
# 2    issue  https://github.com/gakusyutai/gakusyutai.githu...         yuyu31
# 3    issue  https://github.com/jabrena/aqa-tests-experimen...        jabrena
# 4    issue  https://github.com/purpleslurple/PurpleSlurple...  purpleslurple
# ..     ...                                                ...            ...
# 195  issue  https://github.com/neilenns/react-access-code-...       neilenns
# 196  issue  https://github.com/bcmi/Foreground-Object-Sear...    Zhang-Yexun
# 197  issue  https://github.com/LikeLion-at-DGU/backback_ba...      tkdwns414
# 198  issue          https://github.com/tomcl/issie/issues/348          tomcl
# 199  issue  https://github.com/vitabletech/SnippetMaster/i...   msrajawat298
#
#                                        RepoName RepoLanguage  Number  \
# 0                              Tommie1236/mipsi          CSS       3
# 1                             ariel1985/aipages         HTML       4
# 2               gakusyutai/gakusyutai.github.io         HTML      31
# 3                 jabrena/aqa-tests-experiments         Java       4
# 4                   purpleslurple/PurpleSlurple          PHP     109
# ..                                          ...          ...     ...
# 195              neilenns/react-access-code-map   TypeScript       5
# 196  bcmi/Foreground-Object-Search-Dataset-FOSD       Python       2
# 197            LikeLion-at-DGU/backback_backend       Python      61
# 198                                 tomcl/issie           F#     348
# 199                   vitabletech/SnippetMaster         HTML      29
#
#                                                  Title  \
# 0    be able to start/stop/reboot/send commands to ...
# 1    Before production: rasa URL needs to be a glob...
# 2                                        ハンバーガーメニューの実装
# 3                  Run a test in multiple java distros
# 4            Store annotations in local storage (duh!)
# ..                                                 ...
# 195      Add axios interceptor to set the header token
# 196      按照requirement.txt中的numpy版本不能使用import fiftyone
# 197                                    오운완 level 기능 추가
# 198       Modern wire circles placed in wrong position
# 199  Create own github workflow action repo for pub...
#
#                                                   Body             CreatedAt  \
# 0    https://chat.openai.com/share/b50a1f89-6c17-41...  2023-09-10T11:34:10Z
# 1    https://chat.openai.com/share/e5079f09-2835-49...  2023-09-13T20:58:03Z
# 2    - https://chat.openai.com/share/8b0f517f-1aaf-...  2023-07-23T15:38:42Z
# 3    - https://chat.openai.com/share/e169e9a7-40c5-...  2023-07-07T20:30:07Z
# 4    https://chat.openai.com/share/86580fc7-2c60-49...  2023-09-10T02:36:28Z
# ..                                                 ...                   ...
# 195  Code from ChatGPT: https://chat.openai.com/sha...  2023-07-03T15:42:08Z
# 196  ![image](https://github.com/bcmi/Foreground-Ob...  2023-08-19T00:57:43Z
# 197  1. Profile 모델에 completed_cnt 필드를 추가합니다.(read_o...  2023-08-10T21:00:26Z
# 198  Bug:\r\n\r\nWhen two wires are identical for f...  2023-08-07T17:40:02Z
# 199  https://chat.openai.com/share/9bb9c3d1-c6b1-4a...  2023-06-03T09:35:16Z
#
#                  ClosedAt             UpdatedAt   State  \
# 0                    None  2023-09-10T11:36:02Z    OPEN
# 1                    None  2023-09-13T22:41:28Z    OPEN
# 2                    None  2023-07-23T15:38:42Z    OPEN
# 3                    None  2023-07-08T11:56:45Z    OPEN
# 4                    None  2023-09-10T02:36:28Z    OPEN
# ..                    ...                   ...     ...
# 195  2023-07-08T19:17:38Z  2023-07-08T19:17:38Z  CLOSED
# 196  2023-08-26T01:04:06Z  2023-08-26T01:04:06Z  CLOSED
# 197  2023-08-14T05:45:55Z  2023-08-14T05:45:55Z  CLOSED
# 198                  None  2023-09-04T03:08:52Z    OPEN
# 199  2023-08-05T13:28:45Z  2023-08-05T13:28:45Z  CLOSED
#
#                                         ChatgptSharing
# 0    [{'URL': 'https://chat.openai.com/share/b50a1f...
# 1    [{'URL': 'https://chat.openai.com/share/e5079f...
# 2    [{'URL': 'https://chat.openai.com/share/795827...
# 3    [{'URL': 'https://chat.openai.com/share/b508dd...
# 4    [{'URL': 'https://chat.openai.com/share/86580f...
# ..                                                 ...
# 195  [{'URL': 'https://chat.openai.com/share/861115...
# 196  [{'URL': 'https://chat.openai.com/share/0b7c3b...
# 197  [{'URL': 'https://chat.openai.com/share/27e5de...
# 198  [{'URL': 'https://chat.openai.com/share/4141ee...
# 199  [{'URL': 'https://chat.openai.com/share/9bb9c3...
#
# [200 rows x 13 columns]
# object    12
# int64      1
# dtype: int64

# %%
refactoring_df.dtypes == 'object'  # showing the columns with object data type
# Out:
# Type               True
# URL                True
# Author             True
# RepoName           True
# RepoLanguage       True
# Number            False
# Title              True
# Body               True
# CreatedAt          True
# ClosedAt           True
# UpdatedAt          True
# State              True
# ChatgptSharing     True
# dtype: bool

# %%
"""
As a part of the data cleaning process, we will perform the following four steps:

1. Remove the duplicate rows

2. Finding how many columns have missing data and in what quantity?

3. Replace missing fields with alternative values, For ex: RepoLanguage==None will be replace with RepoLanguage==Multiple Languages

"""
# Out:
# '\nAs a part of the data cleaning process, we will perform the following four steps:\n\n1. Remove the duplicate rows\n\n2. Finding how many columns have missing data and in what quantity?\n\n3. Replace missing fields with alternative values, For ex: RepoLanguage==None will be replace with RepoLanguage==Multiple Languages\n\n'

# %%
# Removing the duplicate rows
# refactoring_df.drop_duplicates()

# %%
# checking the nan/null values in the data
refactoring_df.isnull().sum().sort_values(ascending=False)


# As we can see that there are 
#     1. 122 rows with missing data in the `RepoLanguage` field and 
#     2. 100 rows with missing data in the `MergedAt` field
#     3. 79 rows with missing data in the `ClosedAt` field
# Out:
# ClosedAt          229
# RepoLanguage       34
# ChatgptSharing      0
# State               0
# UpdatedAt           0
# CreatedAt           0
# Body                0
# Title               0
# Number              0
# RepoName            0
# Author              0
# URL                 0
# Type                0
# dtype: int64

# %%
refactoring_df.dropna(axis = 0, subset = ['ChatgptSharing'], how = 'any', inplace=True)

print("The filtered data set has {} rows and {} columns".format(refactoring_df.shape[0], refactoring_df.shape[1]))
# Out:
# The filtered data set has 422 rows and 13 columns

# %%
# For missing `RepoLanguage` field, we are forming it using `Multiple language` as we have checked that multiple programming
# languages are being used in certain repositories and their RepoLanguage is not set, So by default their value is None.

# Define a function to fill null values in 'RepoLanguage' column
def replace_repoLanguage_func(row):    
    if pd.isnull(row['RepoLanguage']):
        return "Multiple Languages"
    
    return row['RepoLanguage']
    
def replace_closedAt_func(row):
    if pd.isnull(row['ClosedAt']):
        return "0000-00-00T00:00:00Z"
    
    return row['ClosedAt']
    
	
# # Apply the lambda function to update the 'None' column
refactoring_df['RepoLanguage'] = refactoring_df.apply(replace_repoLanguage_func, axis=1)
refactoring_df['ClosedAt'] = refactoring_df.apply(replace_closedAt_func, axis=1)

refactoring_df.isnull().sum().sort_values(ascending=False)
# Out:
# ChatgptSharing    0
# State             0
# UpdatedAt         0
# ClosedAt          0
# CreatedAt         0
# Body              0
# Title             0
# Number            0
# RepoLanguage      0
# RepoName          0
# Author            0
# URL               0
# Type              0
# dtype: int64

# %%
total_no_open = len(refactoring_df["State"]=="OPEN")
total_no_merged = len(refactoring_df["State"]=="MERGED")
total_no_closed = len(refactoring_df["State"]=="CLOSED")
labels = ['Open', 'Closed & Merged']
sizes = [total_no_open, total_no_closed+total_no_merged]  
# These values represent the percentage distribution of each category

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Display the chart
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular
plt.show()

# %%
import sqlite3
import datetime
# Connect to or create an SQLite database
conn = sqlite3.connect('my_database.db')

# Create a cursor
cursor = conn.cursor()

cursor.execute('DROP TABLE github_issues_table')
# Create a table
cursor.execute('''CREATE TABLE IF NOT EXISTS github_issues_table (
                     Id TEXT PRIMARY KEY,
                     ClosedAt TEXT,
                     UpdatedAt TEXT,
                     CreatedAt TEXT,
                     ChatgptSharing TEXT,
                     State TEXT,
                     Body TEXT,
                     Title TEXT,
                     Number INTEGER,
                     RepoLanguage TEXT,
                     RepoName TEXT,
                     Author TEXT,
                     URL TEXT
                 )''')

# Insert data into the table
for index, item in refactoring_df.iterrows():
    Id = str(item['RepoName'])+"_"+str(item['Number'])
    ClosedAt = str(item['ClosedAt'])
    UpdatedAt = str(item['UpdatedAt'])
    CreatedAt = str(item['CreatedAt'])
    ChatgptSharing = str(item['ChatgptSharing'])
    State = str(item['State'])
    Body = str(item['Body'])
    Title = str(item['Title'])
    Number = item['Number']
    RepoLanguage = str(item['RepoLanguage'])
    RepoName = str(item['RepoName'])
    Author = str(item['Author'])
    URL = str(item['URL'])
    cursor.execute('INSERT INTO github_issues_table(Id,ClosedAt,ChatgptSharing,State,UpdatedAt,CreatedAt,Body,Title,Number,RepoLanguage,RepoName,Author,URL) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)',(Id, ClosedAt, ChatgptSharing,State,UpdatedAt,CreatedAt,Body,Title,Number,RepoLanguage,RepoName,Author,URL))


# Commit changes
conn.commit()

# Close the connection
conn.close()

# %%
from tabulate import tabulate
conn = sqlite3.connect('my_database.db')

# Create a cursor
cursor = conn.cursor()
table_name = 'github_issues_table'  # Replace with the name of your table

# Check if the table exists
cursor.execute(f"SELECT name FROM sqlite_master WHERE type='table' AND name='{table_name}'")
table_exists = cursor.fetchone() is not None

if table_exists:
    print(f"Table '{table_name}' exists.")
    
    # Execute a SELECT query to retrieve values
    cursor.execute(f"SELECT * FROM {table_name}")
    
    # Fetch all the rows from the result set
    rows = cursor.fetchall()

    # Display the values
    #for row in rows:
     #   print(row)

    column_names = [desc[0] for desc in cursor.description]

    # Display the values in a formatted tabl
    if rows:
        # Use the tabulate library to format the data as a table
        table = tabulate(rows, headers=column_names, tablefmt='grid')
        print(table)
    else:
        print(f"No data found in table '{table_name}'")

else:
    print(f"Table '{table_name}' does not exist.")

# Close the connection
conn.close()
# Out:
# Table 'github_issues_table' exists.
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-13-7d5f69491806> in <module>()
#      28     if rows:
#      29         # Use the tabulate library to format the data as a table
# ---> 30         table = tabulate(rows, headers=column_names, tablefmt='grid')
#      31         print(table)
#      32     else:
#
# F:\software\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\tabulate.py in tabulate(tabular_data, headers, tablefmt, floatfmt, numalign, stralign, missingval, showindex, disable_numparse, colalign, maxcolwidths)
#    1730         tablefmt = _table_formats.get(tablefmt, _table_formats["simple"])
#    1731
# -> 1732     return _format_table(tablefmt, headers, rows, minwidths, aligns, is_multiline)
#    1733
#    1734
#
# F:\software\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\tabulate.py in _format_table(fmt, headers, rows, colwidths, colaligns, is_multiline)
#    1870         # initial rows with a line below
#    1871         for row in padded_rows[:-1]:
# -> 1872             append_row(lines, row, padded_widths, colaligns, fmt.datarow)
#    1873             _append_line(lines, padded_widths, colaligns, fmt.linebetweenrows)
#    1874         # the last row without a line below
#
# F:\software\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\tabulate.py in _append_multiline_row(lines, padded_multiline_cells, padded_widths, colaligns, rowfmt, pad)
#    1807     for ln in lines_cells:
#    1808         padded_ln = _pad_row(ln, pad)
# -> 1809         _append_basic_row(lines, padded_ln, colwidths, colaligns, rowfmt)
#    1810     return lines
#    1811
#
# F:\software\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\tabulate.py in _append_basic_row(lines, padded_cells, colwidths, colaligns, rowfmt)
#    1790
#    1791 def _append_basic_row(lines, padded_cells, colwidths, colaligns, rowfmt):
# -> 1792     lines.append(_build_row(padded_cells, colwidths, colaligns, rowfmt))
#    1793     return lines
#    1794
#
# F:\software\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\tabulate.py in _build_row(padded_cells, colwidths, colaligns, rowfmt)
#    1786         return rowfmt(padded_cells, colwidths, colaligns)
#    1787     else:
# -> 1788         return _build_simple_row(padded_cells, rowfmt)
#    1789
#    1790
#
# F:\software\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\tabulate.py in _build_simple_row(padded_cells, rowfmt)
#    1776     "Format row according to DataRow format without padding."
#    1777     begin, sep, end = rowfmt
# -> 1778     return (begin + sep.join(padded_cells) + end).rstrip()
#    1779
#    1780
#
# MemoryError:
